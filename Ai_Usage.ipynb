# %% [markdown]
# **AI-Powered Industry Skill Demand Forecasting**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv("ai_tool_usage_india_synthetic.csv")
print(df)
# Out:
#       User_ID              State Age_Group  Gender     AI_Tool  \
# 0           1          Rajasthan       55+  Female     ChatGPT
# 1           2  Jammu and Kashmir     18-24  Female  Midjourney
# 2           3              Assam     25-34  Female     Copilot
# 3           4             Odisha     25-34    Male      Runway
# 4           5          Karnataka     45-54    Male      DALL·E
# ...       ...                ...       ...     ...         ...
# 9995     9996        Maharashtra     18-24  Female      Runway
# 9996     9997             Odisha     35-44    Male  Midjourney
# 9997     9998        Maharashtra     25-34  Female     ChatGPT
# 9998     9999      Uttar Pradesh       55+   Other      DALL·E
# 9999    10000        Maharashtra     35-44    Male      DALL·E
#
#      Usage_Frequency            Purpose
# 0             Weekly  Creative Projects
# 1              Daily              Other
# 2            Monthly              Other
# 3              Daily  Creative Projects
# 4            Monthly               Work
# ...              ...                ...
# 9995         Monthly          Education
# 9996         Monthly               Work
# 9997          Weekly  Creative Projects
# 9998           Daily              Other
# 9999           Daily      Entertainment
#
# [10000 rows x 7 columns]

# %%
sns.set(style="whitegrid")

# %%
plt.figure(figsize=(10, 6))
ai_tool_counts = df['AI_Tool'].value_counts()
sns.barplot(x=ai_tool_counts.values, y=ai_tool_counts.index, palette="viridis")
plt.title('Total AI Tool Usage Count')
plt.xlabel('Number of Users')
plt.ylabel('AI Tool')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-9-4284728271>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=ai_tool_counts.values, y=ai_tool_counts.index, palette="viridis")

# %%
# 2. Usage frequency distribution
plt.figure(figsize=(8, 5))
freq_counts = df['Usage_Frequency'].value_counts()
sns.barplot(x=freq_counts.index, y=freq_counts.values, palette="coolwarm")
plt.title('Usage Frequency Distribution')
plt.xlabel('Usage Frequency')
plt.ylabel('Number of Users')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-10-1983259111>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=freq_counts.index, y=freq_counts.values, palette="coolwarm")

# %%
# Count users in each age group
age_counts = df['Age_Group'].value_counts()

# Create the plot
plt.figure(figsize=(8, 5))
sns.barplot(x=age_counts.index, y=age_counts.values, palette="Set2")
plt.title('AI Tool Usage by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Number of Users')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-13-1368415694>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=age_counts.index, y=age_counts.values, palette="Set2")

# %%
# 3. Purpose of usage
plt.figure(figsize=(8, 5))
purpose_counts = df['Purpose'].value_counts()
sns.barplot(x=purpose_counts.index, y=purpose_counts.values, palette="Set2")
plt.title('Purpose of AI Tool Usage')
plt.xlabel('Purpose')
plt.ylabel('Number of Users')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-11-169148519>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=purpose_counts.index, y=purpose_counts.values, palette="Set2")

# %%
# 4. Top 10 states using AI tools
plt.figure(figsize=(12, 6))
top_states = df['State'].value_counts().nlargest(10)
sns.barplot(y=top_states.index, x=top_states.values, palette="magma")
plt.title('Top 10 States Using AI Tools')
plt.xlabel('Number of Users')
plt.ylabel('State')
plt.show()
# Out:
# <ipython-input-12-2484880849>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top_states.index, x=top_states.values, palette="magma")
